# %%
from dotenv import load_dotenv
from openai import OpenAI
from utils import create_intro_paragraph, generate_image, display_image

load_dotenv()
# Out:
# True

# %%
client = OpenAI()
intro = create_intro_paragraph(client, user_prompt="Write me an introductory paragraph about conspiracies related to the 30 Years War.")
image_url = generate_image(client, intro = intro)
display_image(file_path="images", image_url = image_url, save = True)

# %%
print(intro)
# Out:
# While the 30 Years War, which ravaged Europe from 1618 to 1648, is often seen as a historical conflict rooted in religion and political power struggles, a deeper investigation reveals a web of conspiracies that could extend even into modern times. From secret societies vying for control of European politics to clandestine deals involving the early banks of Amsterdam that may have influenced the course of the war, these theories are ripe for exploration. Interestingly, connections can be drawn to today’s San Francisco Bay Area, where universities and tech companies delve into historical research projects that may hold remnants of these secrets. Could the echoes of these conspiracies still resonate today, shaping narratives we’ve yet to fully uncover? Stay tuned as we delve into this fascinating intersection of history and modern intrigue.
